# %%
from tkinter import*
window=Tk()
window.title('Simple Calculator')
window.geometry("400x368")

def click():
    print(entry1.insert(END,number))

def c():
    entry1.delete(0,END)

def AC():
    a=entry1.get()
    length=len(a)
    entry1.delete(length-1,END)
def operation():
    while True:
        global e
        m=entry1.get()
        r=str(m)
        w=eval(r)
        e=('=',w)
        return e
def final():
    global e
    operation()
    entry1.insert(END,e)
def error():
    try:
        final()
    except:
        clear()
        entry1.insert(END,'syntax errror')

    



button1=Button(window,text='AC',width=9,height=0,font=('Arial bold',15),fg='black',bg='blue',command=AC).place(x=0,y=150)
button1=Button(window,text='C',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=c).place(x=100,y=150)
button1=Button(window,text='%',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'%')).place(x=200,y=150)
button1=Button(window,text='/',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'/')).place(x=300,y=150)


button1=Button(window,text='7',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'7')).place(x=0,y=191) 
button1=Button(window,text='8',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'8')).place(x=100,y=191)
button1=Button(window,text='9',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'9')).place(x=200,y=191)
button1=Button(window,text='*',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'*')).place(x=300,y=191)



button1=Button(window,text='4',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'4')).place(x=0,y=232)
button1=Button(window,text='5',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'5')).place(x=100,y=232)
button1=Button(window,text='6',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'6')).place(x=200,y=232)
button1=Button(window,text='-',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'-')).place(x=300,y=232)



button1=Button(window,text='1',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'1')).place(x=0,y=273)
button1=Button(window,text='2',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'2')).place(x=100,y=273)
button1=Button(window,text='3',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'3')).place(x=200,y=273)
button1=Button(window,text='+',width=9,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'+')).place(x=300,y=273)



button1=Button(window,text='0',width=12,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'0')).place(x=0,y=314)
button1=Button(window,text='.',width=12,height=0,font=('Arial bold',15),fg='black',bg='white',command=lambda:entry1.insert(END,'.')).place(x=150,y=314)
button1=Button(window,text='=',width=9,height=1,font=('Arial bold',15),fg='white',bg='black',command=error).place(x=300,y=314)












entry1=Entry(window,fg='black',bg='white',font=('Arial bold',30))
entry1.place(x=0,y=1,width=400,height=100)


window.configure(bg="white")
window.mainloop()
